# %% [markdown]
# <a href="https://colab.research.google.com/github/luluv-ie/newrepo/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter name: ")
age = input("Enter age: ")
course = input("Enter course: ")
print("Name: " + name)
print("Age: " + age)
print("Course: " + course)
# Out:
# Enter name: Lexine
# Enter age: 14
# Enter course: computer science
# Name: Lexine
# Age: 14
# Course: computer science

# %%
name = input("Enter name: ")
exam_score = int(input("Enter exam score: "))

if exam_score >= 75:
    print("Pass")
elif exam_score < 75:
    print("Fail")
# Out:
# Enter name: lexine
# Enter exam score: 39
# Fail

# %%
name = input("Enter name: ")
score = int(input("Enter score: "))

if score >= 90:
    print("A")
elif score >= 80:
    print("B")
elif score >= 70:
    print("C")
else:
    print("F")
# Out:
# Enter name: LEXINE
# Enter score: 71
# C
